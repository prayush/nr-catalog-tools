# %%
import mayawaves
import sxs
# Out:
# /home/prayush/miniconda3/envs/igwn-py311/lib/python3.11/site-packages/numba/core/cpu.py:99: UserWarning: Numba extension module 'awkward.numba' failed to load due to 'AttributeError(module 'numpy' has no attribute 'AxisError')'.
#   numba.core.entrypoints.init_all()

# %%
sxs_df = sxs.load("dataframe")
# Out:
# Loading SXS simulations using latest tag 'v3.0.0', published at 2025-05-14T18:17:30Z.

# %%
sxs_df[sxs_df["deprecated"] != True]
# Out:
#                deprecated  reference_mass_ratio  reference_chi_eff  \
# SXS:BBH:0069        False              1.000000       1.528972e-07
# SXS:BBH:0078        False              1.499507       2.080200e-04
# SXS:BBH:0082        False              1.500630      -2.282971e-04
# SXS:BBH:0087        False              1.000000       1.560551e-07
# SXS:BBH:0088        False              1.000459      -1.014844e-04
# ...                   ...                   ...                ...
# SXS:NSNS:0006       False              1.199984       0.000000e+00
# SXS:NSNS:0007       False              0.831025       0.000000e+00
# SXS:NSNS:0008       False              1.000000       0.000000e+00
# SXS:NSNS:0009       False              1.099992       0.000000e+00
# SXS:NSNS:0010       False              1.199984       0.000000e+00
#
#                reference_chi1_perp  reference_chi2_perp  \
# SXS:BBH:0069          9.322138e-10         1.581355e-09
# ...

# %%
def get_area_square(side_length):
    area = side_length **2
    return area

# %%
def area(radius=1):
    return 3.14 * radius ** 2

side_len = 1e99

class Circle(object):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

class Square(object):
    def __init__(self, side_length):
        self.side_len = side_length # 1. creating 2. assigning

    def perimeter(self):
        return 4 * self.side_len

    def area(self):
        return self.side_len ** 2
    
    def diagonal(self):
        return self.side_len * (2**0.5)
    
    def four_times_area(self):
        return 4 * self.area()
    
    # def __call__(self):
    #     return "I'm a square"
    
    def _get_intrinsic_parameters(self):
        def __call__(self):
            return "I'm a square"
        return
    
    def _load_dimless_surrogate(self):
        return 
    
MY_SHAPES = {
    "square": Square,
    "circle": Circle
}

# %%
sur = MY_SHAPES["square"](10)

# %%
sur.diagonal()
# Out:
# 14.142135623730951

# %%
sq = Square(10)

# %%
sur()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sur()
#
# TypeError: 'Square' object is not callable

# %%
"%s/%s.h5" % ("myhome", "myroom")
# Out:
# 'myhome/myroom.h5'

# %%
"{}/{}.h5".format("myhome", "myroom")
# Out:
# 'myhome/myroom.h5'
